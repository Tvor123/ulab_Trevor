# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# Your comment here

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
# Your code here (WITHOUT NUMPY! or any other modules/libraries/packages)
def orbital_period(a):
    # Calculates orbital period Keplers 3rd
    period = (a ** 3) ** 0.5
    return period

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
planet_a = 0.5
planet_b = 1.0
planet_c = 1.5
print(orbital_period(planet_a))
print(orbital_period(planet_b))
print(orbital_period(planet_c))
# Out:
# 0.3535533905932738
# 1.0
# 1.8371173070873836

# %% [markdown]
# Import `numpy` in the cell below.

# %%
# Your code here
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# Your comment (2 sentences)
#you need to call numpy once in a jupyter notebook. Once called it applies to all cells

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
# Your code here
def orbital_period_np(a):
    #calculates time  period using keplers and numpy
    period = np.power(a, 1.5)
    return period

# %% [markdown]
# Import the `time` package in the cell below.

# %%
# Your code here
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
# Your code here
a = 5

start_time = time.perf_counter()
orbital_period(a)
end_time = time.perf_counter()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")

start_time = time.perf_counter()
orbital_period_np(a)
end_time = time.perf_counter()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Elapsed time: 0.0001452000578865409 seconds
# Elapsed time: 0.00011589995119720697 seconds

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
#The np function is faster, it does one action rather than two

# %% [markdown]
# Define a **list** in the cell below that contains a least 1000 semi-major axis values.

# %%
# Your code here
from numpy import random

radii = 5*random.rand(100000)

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
# Your code here
start_time = time.perf_counter()
for i in range(len(radii)):
    orbital_period(radii[i])
end_time = time.perf_counter()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")

start_time = time.perf_counter()
for i in range(len(radii)):
    orbital_period_np(radii[i])
end_time = time.perf_counter()

elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Elapsed time: 0.20703759999014437 seconds
# Elapsed time: 0.1778746999334544 seconds

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
#The np function is faster, this shows that the np functions process faster than the general python functions

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
# Your code 
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

def find_planets(temp):
    #creates new array of radii with temp less than 350K
    filtered_radii = []
    for i in range(len(temp)):
        if temp[i] < 350:
            filtered_radii.append(radii[i])
    return filtered_radii

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
# Your code here
print(radii[:3])
# Out:
# [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
# Your code here
dict(zip(radii, temperatures))
# Out:
# {1.2: 300, 0.8: 400, 1.5: 350, 2.0: 280, 1.0: 500, 0.6: 450}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
# Your code here
name = ['a', 'b', 'c', 'd', 'e', 'f']
{name: {"radius": r, "temperature": t} for name, r, t in zip(name, radii, temperatures)}
# Out:
# {'a': {'radius': 1.2, 'temperature': 300},
#  'b': {'radius': 0.8, 'temperature': 400},
#  'c': {'radius': 1.5, 'temperature': 350},
#  'd': {'radius': 2.0, 'temperature': 280},
#  'e': {'radius': 1.0, 'temperature': 500},
#  'f': {'radius': 0.6, 'temperature': 450}}

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
# Your code here
{name: {"radius": r, "temperature": t} for name, r, t in zip(name, radii, temperatures) if r >= 1.0 and r <= 2.0}
# Out:
# {'a': {'radius': 1.2, 'temperature': 300},
#  'c': {'radius': 1.5, 'temperature': 350},
#  'd': {'radius': 2.0, 'temperature': 280},
#  'e': {'radius': 1.0, 'temperature': 500}}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
# Your code here
radii = 5 * random.rand(100000)

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
# Your code here
print(np.mean(radii))
print(np.median(radii))
print(np.min(radii))
print(np.max(radii))
# Out:
# 2.4987210636613995
# 2.501367390289235
# 3.1455803223834344e-05
# 4.999914882282214

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
# Your code here
new_arr = np.array_split(radii, 5)
#splits the array into five arrays
print(new_arr)
# Out:
# [array([0.91708755, 4.73282963, 1.45119263, ..., 2.36679238, 4.02000449,
#        1.4611037 ]), array([1.70477418, 2.18908098, 0.57312276, ..., 1.86470304, 0.47310527,
#        1.06235447]), array([0.02039751, 1.23171529, 3.80328938, ..., 0.31667948, 3.01992908,
#        2.38862151]), array([0.92348404, 4.14812457, 4.59659292, ..., 2.72023202, 0.48002981,
#        3.98080241]), array([0.55542162, 2.45590924, 1.43782974, ..., 1.87330868, 0.55637226,
#        1.95110599])]

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
# Your code here
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
planet_data = [radii, temperatures]

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
# I'm not sure what this means
for i in range(1):
    print(planet_data[1][2])
# Out:
# 350

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
#I'm not sure what this means either
print(planet_data[1][2])
# Out:
# 350

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
# Your code here
semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
orbital_periods = []
for i in range(len(semi_major_axes)):
    orbital_periods.append(orbital_period_np(semi_major_axes[i]))

import matplotlib.pyplot as plt
plt.title('Orbital Periods of Exoplanets')
plt.xlabel('semi-major axes')
plt.ylabel('orbital periods')
plt.plot(semi_major_axes, orbital_periods, 'o')
plt.show()

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
plt.title('Equilibrium Tempratures vs. Radii')
plt.xlabel('radius')
plt.ylabel('temperature')

radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
plt.bar(radii, temperatures)

plt.show()

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
# Your code here
fig, ax = plt.subplots(1, 2, figsize = (10, 5))
ax[0].plot(semi_major_axes, orbital_periods, 'o')
ax[0].set_title('Orbital Periods of Exoplanets')
ax[0].set_xlabel('semi-major axes')
ax[0].set_ylabel('orbital periods')
ax[1].set_title('Equilibrium Tempratures vs. Radii')
ax[1].set_xlabel('radius')
ax[1].set_ylabel('temperature')
ax[1].bar(radii, temperatures)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
# Your code here
from orbital_per import orbital_period_test
print(orbital_period_test(15))
# Out:
# 58.09475019311125
